# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/danpele/Time-Series-Analysis/blob/main/EN/Course_Notebooks/chapter10_lecture_notebook.ipynb)
#
# ---

# %% [markdown]
# # Chapter 10: Comprehensive Review
#
# **Complete Time Series Analysis with Real Data**
#
# **Course:** Time Series Analysis and Forecasting
# **Program:** Bachelor program, Faculty of Cybernetics, Statistics and Economic Informatics, Bucharest University of Economic Studies, Romania
# **Academic Year:** 2025-2026
#
# ---
#
# ## Learning Objectives
#
# This comprehensive review demonstrates the complete time series analysis workflow using **real data** with proper **train/validation/test** methodology:
#
# 1. **Case Study 1: Bitcoin** - ARIMA-GARCH with proper volatility forecasting evaluation
# 2. **Case Study 2: Sunspots** - Long-cycle seasonal data with cross-validation
# 3. **Case Study 3: US Unemployment** - Structural breaks with Prophet
# 4. **Case Study 4: Multivariate Analysis** - VAR model with Granger causality
#
# ### Key Methodology: Train/Validation/Test Split (70/20/10)
#
# ```
# |<-------- Training (70%) -------->|<-- Validation (20%) -->|<-- Test (10%) -->|
# |                                  |                        |                  |
# |     Fit model parameters         |  Select hyperparameters|  Final evaluate  |
# |                                  |     Compare models     |  Report metrics  |
# ```
#
# **Why this matters:**
# - **Training set (70%)**: Used to estimate model parameters
# - **Validation set (20%)**: Used to select hyperparameters and compare models
# - **Test set (10%)**: Held out until the very end for unbiased final evaluation

# %% [markdown]
# ## Setup and Imports

# %%
# Install required packages (for Colab)
import sys
import os
if 'google.colab' in sys.modules:
    # !pip install prophet arch statsmodels yfinance pandas-datareader -q

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# Statistical tests and models
from statsmodels.tsa.stattools import adfuller, kpss, grangercausalitytests
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima.model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.api import VAR
from statsmodels.tsa.seasonal import seasonal_decompose

# GARCH
try:
    from arch import arch_model
    HAS_ARCH = True
except ImportError:
    HAS_ARCH = False
    print("arch not installed. Install with: pip install arch")

# Prophet
try:
    from prophet import Prophet
    HAS_PROPHET = True
except ImportError:
    HAS_PROPHET = False
    print("Prophet not installed. Install with: pip install prophet")

from sklearn.metrics import mean_squared_error, mean_absolute_error

# Plotting style - CONSISTENT WITH SLIDES
plt.rcParams['figure.figsize'] = (12, 5)
plt.rcParams['font.size'] = 11
plt.rcParams['axes.facecolor'] = 'white'
plt.rcParams['figure.facecolor'] = 'white'
plt.rcParams['axes.grid'] = False
plt.rcParams['axes.spines.top'] = False
plt.rcParams['axes.spines.right'] = False
plt.rcParams['legend.frameon'] = False
plt.rcParams['savefig.dpi'] = 150
plt.rcParams['savefig.bbox'] = 'tight'

COLORS = {'blue': '#1A3A6E', 'red': '#DC3545', 'green': '#2E7D32', 
          'orange': '#E67E22', 'gray': '#666666', 'purple': '#8E44AD'}

# Chart output directory (same as slides)
CHARTS_DIR = 'charts/'
os.makedirs(CHARTS_DIR, exist_ok=True)

def save_chart(name):
    """Save chart to PDF and PNG for slides"""
    plt.savefig(f'{CHARTS_DIR}{name}.pdf')
    plt.savefig(f'{CHARTS_DIR}{name}.png')
    print(f"  Saved: {name}.pdf")

print("Setup complete!")
print(f"ARCH/GARCH available: {HAS_ARCH}")
print(f"Prophet available: {HAS_PROPHET}")
print(f"Charts will be saved to: {CHARTS_DIR}")
# Out:
# Setup complete!
# ARCH/GARCH available: True
# Prophet available: True
# Charts will be saved to: charts/

# %% [markdown]
# ## Helper Functions

# %%
def test_stationarity(series, name):
    """Run ADF and KPSS tests for stationarity"""
    print(f"\nStationarity Tests for {name}")
    print("-" * 50)
    
    # ADF Test (H0: unit root exists = non-stationary)
    adf_result = adfuller(series.dropna(), autolag='AIC')
    adf_stationary = adf_result[1] < 0.05
    print(f"ADF Test:")
    print(f"  Statistic: {adf_result[0]:.4f}")
    print(f"  p-value: {adf_result[1]:.6f}")
    print(f"  Conclusion: {'STATIONARY' if adf_stationary else 'NON-STATIONARY'}")
    
    # KPSS Test (H0: stationary)
    kpss_result = kpss(series.dropna(), regression='c', nlags='auto')
    kpss_stationary = kpss_result[1] > 0.05
    print(f"\nKPSS Test:")
    print(f"  Statistic: {kpss_result[0]:.4f}")
    print(f"  p-value: {kpss_result[1]:.4f}")
    print(f"  Conclusion: {'STATIONARY' if kpss_stationary else 'NON-STATIONARY'}")
    
    both_agree = adf_stationary and kpss_stationary
    print(f"\nOverall: {'STATIONARY' if both_agree else 'NON-STATIONARY or INCONCLUSIVE'}")
    return both_agree


def calc_metrics(actual, predicted, name=""):
    """Calculate forecast accuracy metrics"""
    actual = np.array(actual)
    predicted = np.array(predicted)
    
    rmse = np.sqrt(mean_squared_error(actual, predicted))
    mae = mean_absolute_error(actual, predicted)
    # Avoid division by zero in MAPE
    mape = np.mean(np.abs((actual - predicted) / (actual + 1e-10))) * 100
    
    if name:
        print(f"\n{name} Metrics:")
        print(f"  RMSE: {rmse:.4f}")
        print(f"  MAE:  {mae:.4f}")
        print(f"  MAPE: {mape:.2f}%")
    
    return {'rmse': rmse, 'mae': mae, 'mape': mape}


def time_series_split(data, train_pct=0.70, val_pct=0.20, test_pct=0.10):
    """Split time series data into train/validation/test sets
    
    IMPORTANT: For time series, we NEVER shuffle data!
    We preserve temporal order.
    
    Default split: 70% / 20% / 10%
    """
    n = len(data)
    train_end = int(n * train_pct)
    val_end = int(n * (train_pct + val_pct))
    
    train = data.iloc[:train_end].copy()
    val = data.iloc[train_end:val_end].copy()
    test = data.iloc[val_end:].copy()
    
    print(f"Data Split (Total: {n} observations):")
    print(f"  Training:   {len(train):4d} ({100*len(train)/n:.1f}%)")
    print(f"  Validation: {len(val):4d} ({100*len(val)/n:.1f}%)")
    print(f"  Test:       {len(test):4d} ({100*len(test)/n:.1f}%)")
    
    return train, val, test


print("Helper functions defined!")
# Out:
# Helper functions defined!

# %% [markdown]
# ## Real Data Loading Functions

# %%
def get_bitcoin_data():
    """Fetch REAL Bitcoin daily prices from Yahoo Finance (2019-2025)"""
    import yfinance as yf
    btc = yf.download('BTC-USD', start='2019-01-01', end='2025-01-15', progress=False)
    if len(btc) == 0:
        raise ValueError("Could not load Bitcoin data from Yahoo Finance")
    df = pd.DataFrame({
        'ds': btc.index,
        'price': btc['Close'].values.flatten()
    }).reset_index(drop=True)
    df['returns'] = df['price'].pct_change() * 100
    print(f"Bitcoin: Loaded {len(df)} days of REAL data from Yahoo Finance")
    return df


def get_sunspot_data():
    """Fetch REAL yearly sunspot numbers from statsmodels (1700-present)"""
    import statsmodels.api as sm
    sunspots = sm.datasets.sunspots.load_pandas().data
    sunspots = sunspots[sunspots['YEAR'] >= 1900].copy()
    sunspots['ds'] = pd.to_datetime(sunspots['YEAR'].astype(int), format='%Y')
    sunspots = sunspots.rename(columns={'SUNACTIVITY': 'y'})
    sunspots = sunspots[['ds', 'y']].reset_index(drop=True)
    print(f"Sunspots: Loaded {len(sunspots)} years of REAL data from statsmodels")
    return sunspots


def get_unemployment_data():
    """Fetch REAL US Unemployment Rate from FRED (2010-2025)"""
    import pandas_datareader as pdr
    unemp = pdr.get_data_fred('UNRATE', start='2010-01-01', end='2025-01-15')
    if len(unemp) == 0:
        raise ValueError("Could not load unemployment data from FRED")
    df = pd.DataFrame({
        'ds': unemp.index,
        'y': unemp['UNRATE'].values
    }).reset_index(drop=True)
    print(f"US Unemployment: Loaded {len(df)} months of REAL data from FRED")
    return df


def get_multivariate_economic_data():
    """Fetch multiple economic indicators from FRED for VAR analysis"""
    import pandas_datareader as pdr
    
    start, end = '2000-01-01', '2025-01-15'
    
    # Fetch all series
    gdp = pdr.get_data_fred('GDPC1', start=start, end=end)  # Real GDP (quarterly)
    unemp = pdr.get_data_fred('UNRATE', start=start, end=end)  # Unemployment (monthly)
    inflation = pdr.get_data_fred('CPIAUCSL', start=start, end=end)  # CPI (monthly)
    fed_rate = pdr.get_data_fred('FEDFUNDS', start=start, end=end)  # Fed Funds Rate (monthly)
    
    # Calculate GDP growth BEFORE resampling
    gdp['gdp_growth'] = gdp['GDPC1'].pct_change(4) * 100
    
    # Resample ALL to quarter-end for consistent index
    gdp_q = gdp.resample('QE').last()
    unemp_q = unemp.resample('QE').mean()
    inflation_q = inflation.resample('QE').last()
    fed_q = fed_rate.resample('QE').mean()
    
    # Calculate inflation rate (YoY %)
    inflation_q['inflation'] = inflation_q['CPIAUCSL'].pct_change(4) * 100
    
    # Merge all series
    df = pd.DataFrame({
        'gdp_growth': gdp_q['gdp_growth'],
        'unemployment': unemp_q['UNRATE'],
        'inflation': inflation_q['inflation'],
        'fed_rate': fed_q['FEDFUNDS']
    }).dropna()
    
    if len(df) == 0:
        raise ValueError("Could not merge economic data from FRED")
    
    print(f"Economic Data: Loaded {len(df)} quarters of REAL data from FRED")
    print(f"  Variables: GDP Growth, Unemployment, Inflation, Fed Funds Rate")
    return df


print("Data loading functions defined!")
# Out:
# Data loading functions defined!

# %% [markdown]
# ---
# # Case Study 1: Bitcoin Volatility Analysis
#
# ## Objective
# Model and forecast Bitcoin's volatility using GARCH models.
#
# ## Why GARCH?
# - Financial returns are typically **unpredictable in mean** but **predictable in variance**
# - Volatility clustering: large changes follow large changes
# - GARCH captures this time-varying volatility
#
# ## Methodology
# 1. **Training (70%)**: Estimate GARCH model parameters
# 2. **Validation (20%)**: Compare GARCH(1,1) vs GARCH(2,1) vs GJR-GARCH
# 3. **Test (10%)**: Final out-of-sample evaluation

# %%
# Load Bitcoin data
btc = get_bitcoin_data()

print("\n" + "="*60)
print("BITCOIN DATA OVERVIEW")
print("="*60)
print(f"Period: {btc['ds'].min().date()} to {btc['ds'].max().date()}")
print(f"Observations: {len(btc)} days")
print(f"\nPrice Statistics:")
print(f"  Min:  ${btc['price'].min():,.2f}")
print(f"  Max:  ${btc['price'].max():,.2f}")
print(f"  Mean: ${btc['price'].mean():,.2f}")
print(f"\nReturn Statistics (Daily %):")
print(f"  Mean:     {btc['returns'].mean():.4f}%")
print(f"  Std Dev:  {btc['returns'].std():.4f}%")
print(f"  Skewness: {btc['returns'].skew():.4f} (negative = left tail)")
print(f"  Kurtosis: {btc['returns'].kurtosis():.4f} (>3 = fat tails)")
# Out:
# Bitcoin: Loaded 2206 days of REAL data from Yahoo Finance
#
# ============================================================
# BITCOIN DATA OVERVIEW
# ============================================================
# Period: 2019-01-01 to 2025-01-14
# Observations: 2206 days
#
# Price Statistics:
#   Min:  $3,399.47
#   Max:  $106,140.60
#   Mean: $31,912.23
#
# Return Statistics (Daily %):
#   Mean:     0.2043%
#   Std Dev:  3.3828%
#   Skewness: -0.3121 (negative = left tail)
#   Kurtosis: 9.8848 (>3 = fat tails)

# %%
# Visualize the data - Generate charts matching slides
from scipy.stats import norm

# Chart 1: Bitcoin Returns (btc_returns.pdf)
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(btc['ds'], btc['returns'], color=COLORS['blue'], linewidth=0.5)
ax.axhline(y=0, color='black', linewidth=0.5, alpha=0.3)
ax.set_title('Bitcoin Daily Returns (%)', fontweight='bold')
ax.set_xlabel('Date')
ax.set_ylabel('Return (%)')
plt.tight_layout()
save_chart('btc_returns')
plt.show()

# Chart 2: Squared Returns (btc_squared_returns.pdf)
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(btc['ds'], btc['returns']**2, color=COLORS['orange'], linewidth=0.5)
ax.set_title('Bitcoin Squared Returns (Volatility Proxy)', fontweight='bold')
ax.set_xlabel('Date')
ax.set_ylabel('Return² (%²)')
plt.tight_layout()
save_chart('btc_squared_returns')
plt.show()

# Chart 3: ACF of Squared Returns (btc_acf_squared.pdf)
fig, ax = plt.subplots(figsize=(10, 4))
plot_acf(btc['returns'].dropna()**2, ax=ax, lags=40, alpha=0.05)
ax.set_title('ACF of Squared Returns (Evidence of GARCH Effects)', fontweight='bold')
ax.set_xlabel('Lag')
ax.set_ylabel('Autocorrelation')
plt.tight_layout()
save_chart('btc_acf_squared')
plt.show()

print("\nKey Observations:")
print("1. Returns show VOLATILITY CLUSTERING (periods of high/low volatility)")
print("2. ACF of squared returns shows significant persistence -> GARCH is appropriate")
# Out:
#   Saved: btc_returns.pdf
#   Saved: btc_squared_returns.pdf
#   Saved: btc_acf_squared.pdf
# Key Observations:
# 1. Returns show VOLATILITY CLUSTERING (periods of high/low volatility)
# 2. ACF of squared returns shows significant persistence -> GARCH is appropriate

# %%
# Step 1: Stationarity Testing
print("STEP 1: STATIONARITY TESTING")
print("="*60)

# Test prices (expect non-stationary)
test_stationarity(btc['price'], 'Bitcoin Prices')

# Test returns (expect stationary)
returns = btc['returns'].dropna()
test_stationarity(returns, 'Bitcoin Returns')

print("\n" + "="*60)
print("CONCLUSION: Use RETURNS (not prices) for modeling")
print("="*60)
# Out:
# STEP 1: STATIONARITY TESTING
# ============================================================
#
# Stationarity Tests for Bitcoin Prices
# --------------------------------------------------
# ADF Test:
#   Statistic: -0.3201
#   p-value: 0.922614
#   Conclusion: NON-STATIONARY
#
# KPSS Test:
#   Statistic: 3.9293
#   p-value: 0.0100
#   Conclusion: NON-STATIONARY
#
# Overall: NON-STATIONARY or INCONCLUSIVE
#
# Stationarity Tests for Bitcoin Returns
# --------------------------------------------------
# ADF Test:
#   Statistic: -22.4903
#   p-value: 0.000000
#   Conclusion: STATIONARY
#
# KPSS Test:
#   Statistic: 0.1691
#   p-value: 0.1000
#   Conclusion: STATIONARY
#
# Overall: STATIONARY
#
# ============================================================
# CONCLUSION: Use RETURNS (not prices) for modeling
# ============================================================
# /var/folders/pk/sxdc5n5x6mb322grbvxz_nm40000gp/T/ipykernel_32821/968196761.py:15: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is smaller than the p-value returned.
#
#   kpss_result = kpss(series.dropna(), regression='c', nlags='auto')
# /var/folders/pk/sxdc5n5x6mb322grbvxz_nm40000gp/T/ipykernel_32821/968196761.py:15: InterpolationWarning: The test statistic is outside of the range of p-values available in the
# look-up table. The actual p-value is greater than the p-value returned.
#
#   kpss_result = kpss(series.dropna(), regression='c', nlags='auto')

# %%
# Step 2: Train/Validation/Test Split
print("\nSTEP 2: DATA SPLITTING")
print("="*60)
print("\nFor time series, we ALWAYS preserve temporal order!")
print("Never shuffle - the future cannot predict the past.\n")

# Prepare returns data
btc_returns = btc[['ds', 'returns']].dropna().reset_index(drop=True)

# Split: 70% train, 20% validation, 10% test
train_btc, val_btc, test_btc = time_series_split(btc_returns, 0.70, 0.20, 0.10)

print(f"\nDate Ranges:")
print(f"  Training:   {train_btc['ds'].min().date()} to {train_btc['ds'].max().date()}")
print(f"  Validation: {val_btc['ds'].min().date()} to {val_btc['ds'].max().date()}")
print(f"  Test:       {test_btc['ds'].min().date()} to {test_btc['ds'].max().date()}")
# Out:
# STEP 2: DATA SPLITTING
# ============================================================
#
# For time series, we ALWAYS preserve temporal order!
# Never shuffle - the future cannot predict the past.
#
# Data Split (Total: 2205 observations):
#   Training:   1543 (70.0%)
#   Validation:  441 (20.0%)
#   Test:        221 (10.0%)
#
# Date Ranges:
#   Training:   2019-01-02 to 2023-03-24
#   Validation: 2023-03-25 to 2024-06-07
#   Test:       2024-06-08 to 2025-01-14

# %%
# Step 3: Model Selection on Validation Set
print("\nSTEP 3: MODEL SELECTION (using Validation Set)")
print("="*60)

if HAS_ARCH:
    # Combine train+val for model comparison, but evaluate on val only
    train_returns = train_btc['returns'].values
    val_returns = val_btc['returns'].values
    
    # Models to compare
    models_to_test = {
        'GARCH(1,1)': {'vol': 'Garch', 'p': 1, 'q': 1},
        'GARCH(2,1)': {'vol': 'Garch', 'p': 2, 'q': 1},
        'GJR-GARCH(1,1)': {'vol': 'Garch', 'p': 1, 'o': 1, 'q': 1},
        'EGARCH(1,1)': {'vol': 'EGARCH', 'p': 1, 'q': 1}
    }
    
    results_comparison = {}
    
    print("\nComparing GARCH variants on VALIDATION set:")
    print("-" * 60)
    
    for name, params in models_to_test.items():
        try:
            # Fit on training data
            model = arch_model(train_returns, mean='AR', lags=1, **params)
            res = model.fit(disp='off', show_warning=False)
            
            # Forecast on validation period
            forecast = res.forecast(horizon=len(val_returns), reindex=False)
            vol_forecast = np.sqrt(forecast.variance.values[-1, :])
            
            # Calculate realized volatility (|returns| as proxy)
            realized_vol = np.abs(val_returns)
            
            # Metrics: MAE of volatility forecast
            mae = np.mean(np.abs(realized_vol - vol_forecast))
            
            results_comparison[name] = {
                'AIC': res.aic,
                'BIC': res.bic,
                'Val_MAE': mae,
                'model': res
            }
            
            print(f"{name:20s} AIC: {res.aic:10.2f}  BIC: {res.bic:10.2f}  Val MAE: {mae:.4f}")
        except Exception as e:
            print(f"{name:20s} Failed: {e}")
    
    # Select best model based on validation MAE
    best_model_name = min(results_comparison, key=lambda x: results_comparison[x]['Val_MAE'])
    print(f"\n>>> BEST MODEL (lowest validation MAE): {best_model_name}")
else:
    print("ARCH package not available")
# Out:
# STEP 3: MODEL SELECTION (using Validation Set)
# ============================================================
#
# Comparing GARCH variants on VALIDATION set:
# ------------------------------------------------------------
# GARCH(1,1)           AIC:    8323.87  BIC:    8350.58  Val MAE: 2.5356
# GARCH(2,1)           AIC:    8325.50  BIC:    8357.54  Val MAE: 2.5355
# GJR-GARCH(1,1)       AIC:    8307.49  BIC:    8339.54  Val MAE: 2.5716
# EGARCH(1,1)          Failed: Analytic forecasts not available for horizon > 1
#
# >>> BEST MODEL (lowest validation MAE): GARCH(2,1)

# %%
# Step 4: Final Model - Refit on Train+Val, Evaluate on Test
# Using ROLLING ONE-STEP-AHEAD forecasts (not multi-step which converges to unconditional variance)
print("\nSTEP 4: FINAL EVALUATION (Test Set)")
print("="*60)

if HAS_ARCH:
    # Combine training and validation for final model
    trainval_returns = np.concatenate([train_returns, val_returns])
    test_returns = test_btc['returns'].values

    print(f"\nRefitting {best_model_name} on Training+Validation data")
    print(f"  Training+Validation: {len(trainval_returns)} observations")
    print(f"  Test: {len(test_returns)} observations (HELD OUT until now!)")
    print(f"\n  Using ROLLING ONE-STEP-AHEAD forecasts (dynamic, not flat line)\n")

    # Fit final model on train+val
    best_params = models_to_test[best_model_name]

    # ROLLING ONE-STEP-AHEAD FORECASTS
    # For each day in test, we forecast 1-step ahead using all available data up to that point
    all_returns = np.concatenate([trainval_returns, test_returns])
    test_vol_forecast = np.zeros(len(test_returns))

    for i in range(len(test_returns)):
        # Use all data up to (but not including) current test observation
        history = all_returns[:len(trainval_returns) + i]

        # Fit model on history
        model = arch_model(history, mean='AR', lags=1, **best_params)
        res = model.fit(disp='off', show_warning=False)

        # Forecast 1-step ahead
        forecast = res.forecast(horizon=1, reindex=False)
        test_vol_forecast[i] = np.sqrt(forecast.variance.values[-1, 0])

    # Also fit final model for summary
    final_model = arch_model(trainval_returns, mean='AR', lags=1, **best_params)
    final_results = final_model.fit(disp='off')

    # Calculate test metrics
    test_realized_vol = np.abs(test_returns)
    test_mae = np.mean(np.abs(test_realized_vol - test_vol_forecast))
    test_rmse = np.sqrt(np.mean((test_realized_vol - test_vol_forecast)**2))

    print(f"TEST SET RESULTS (Unbiased Final Evaluation):")
    print(f"  Volatility MAE:  {test_mae:.4f}")
    print(f"  Volatility RMSE: {test_rmse:.4f}")

    # Model summary
    print(f"\n{best_model_name} Model Parameters:")
    print(final_results.summary().tables[1])
# Out:
# STEP 4: FINAL EVALUATION (Test Set)
# ============================================================
#
# Refitting GARCH(2,1) on Training+Validation data
#   Training+Validation: 1984 observations
#   Test: 221 observations (HELD OUT until now!)
#
#   Using ROLLING ONE-STEP-AHEAD forecasts (dynamic, not flat line)
# TEST SET RESULTS (Unbiased Final Evaluation):
#   Volatility MAE:  1.8195
#   Volatility RMSE: 2.1451
#
# GARCH(2,1) Model Parameters:
#                                 Mean Model
# ==========================================================================
#                  coef    std err          t      P>|t|    95.0% Conf. Int.
# --------------------------------------------------------------------------
# Const          0.2397  6.923e-02      3.462  5.354e-04   [  0.104,  0.375]
# y[1]          -0.0415  3.272e-02     -1.268      0.205 [ -0.106,2.263e-02]
# ==========================================================================

# %%
# Visualize final results - Generate charts matching slides
if HAS_ARCH:
    # Chart: GARCH Forecast (garch_forecast.pdf)
    fig, ax = plt.subplots(figsize=(10, 5))
    test_dates = test_btc['ds']
    ax.bar(test_dates, test_realized_vol, color=COLORS['blue'], 
           alpha=0.5, width=2, label='Realized |Returns|')
    ax.plot(test_dates, test_vol_forecast, color=COLORS['red'], 
            linewidth=2, label=f'{best_model_name} Rolling 1-Step Forecast')
    ax.set_title(f'{best_model_name}: Rolling One-Step-Ahead Volatility Forecast', fontweight='bold')
    ax.set_xlabel('Date')
    ax.set_ylabel('Volatility')
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2)
    plt.tight_layout()
    save_chart('garch_forecast')
    plt.show()
    
    # Chart: Rolling vs Multi-step comparison (rolling_vs_multistep.pdf)
    # Show why rolling forecasts are better than multi-step
    fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))
    
    # Multi-step forecast (converges to unconditional variance)
    unconditional_var = np.var(trainval_returns)
    multistep_forecast = np.ones(len(test_returns)) * np.sqrt(unconditional_var)
    
    axes[0].bar(test_dates, test_realized_vol, color=COLORS['blue'], alpha=0.5, width=2, label='Realized')
    axes[0].axhline(y=np.sqrt(unconditional_var), color=COLORS['red'], linewidth=2, 
                    linestyle='--', label='Multi-step (flat)')
    axes[0].set_title('Multi-Step Forecast: Converges to σ', fontweight='bold')
    axes[0].set_xlabel('Date')
    axes[0].set_ylabel('Volatility')
    axes[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=2)
    
    axes[1].bar(test_dates, test_realized_vol, color=COLORS['blue'], alpha=0.5, width=2, label='Realized')
    axes[1].plot(test_dates, test_vol_forecast, color=COLORS['red'], linewidth=2, label='Rolling 1-Step')
    axes[1].set_title('Rolling 1-Step: Captures Dynamics', fontweight='bold')
    axes[1].set_xlabel('Date')
    axes[1].set_ylabel('Volatility')
    axes[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), ncol=2)
    
    plt.tight_layout()
    save_chart('rolling_vs_multistep')
    plt.show()
    
    print("\n" + "="*60)
    print("CASE STUDY 1 SUMMARY: Bitcoin Volatility")
    print("="*60)
    print(f"Best Model: {best_model_name}")
    print(f"Test MAE: {test_mae:.4f}")
    print("\nKey Insight: Rolling one-step-ahead forecasts capture volatility dynamics!")
    print("             (Multi-step forecasts converge to flat unconditional variance)")
# Out:
#   Saved: garch_forecast.pdf
#   Saved: rolling_vs_multistep.pdf
# ============================================================
# CASE STUDY 1 SUMMARY: Bitcoin Volatility
# ============================================================
# Best Model: GARCH(2,1)
# Test MAE: 1.8195
#
# Key Insight: Rolling one-step-ahead forecasts capture volatility dynamics!
#              (Multi-step forecasts converge to flat unconditional variance)

# %% [markdown]
# ---
# # Case Study 2: Sunspot Cycle Analysis
#
# ## Objective
# Model the 11-year solar cycle using Fourier terms.
#
# ## Challenge
# - Seasonal period of 11 years is too long for standard SARIMA
# - Solution: Use Fourier terms as exogenous regressors
#
# ## Methodology
# 1. **Training (70%)**: Fit ARIMA with Fourier terms
# 2. **Validation (20%)**: Select optimal number of Fourier harmonics (K=1,2,3,4)
# 3. **Test (10%)**: Final forecast evaluation

# %%
# Load Sunspot data
sunspots = get_sunspot_data()

print("\n" + "="*60)
print("SUNSPOT DATA OVERVIEW")
print("="*60)
print(f"Period: {sunspots['ds'].min().year} to {sunspots['ds'].max().year}")
print(f"Observations: {len(sunspots)} years")
print(f"\nStatistics:")
print(f"  Mean: {sunspots['y'].mean():.1f}")
print(f"  Std:  {sunspots['y'].std():.1f}")
print(f"  Min:  {sunspots['y'].min():.0f}")
print(f"  Max:  {sunspots['y'].max():.0f}")
print(f"\nKnown Feature: ~11-year Schwabe solar cycle")
# Out:
# Sunspots: Loaded 109 years of REAL data from statsmodels
#
# ============================================================
# SUNSPOT DATA OVERVIEW
# ============================================================
# Period: 1900 to 2008
# Observations: 109 years
#
# Statistics:
#   Mean: 60.1
#   Std:  47.7
#   Min:  1
#   Max:  190
#
# Known Feature: ~11-year Schwabe solar cycle

# %%
# Visualize and confirm the cycle - Generate charts matching slides

# Chart: Sunspots time series (sunspots.pdf)
fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(sunspots['ds'], sunspots['y'], color=COLORS['blue'], linewidth=1)
ax.set_title('Yearly Sunspot Numbers (1900-2008)', fontweight='bold')
ax.set_xlabel('Year')
ax.set_ylabel('Sunspot Count')
plt.tight_layout()
save_chart('sunspots')
plt.show()

# Chart: Sunspots ACF (sunspots_acf.pdf)
fig, ax = plt.subplots(figsize=(10, 4))
plot_acf(sunspots['y'], ax=ax, lags=40, alpha=0.05)
ax.axvline(x=11, color=COLORS['red'], linestyle='--', alpha=0.7, label='11-year lag')
ax.axvline(x=22, color=COLORS['red'], linestyle='--', alpha=0.7)
ax.set_title('ACF: Confirms ~11-year Solar Cycle', fontweight='bold')
ax.set_xlabel('Lag (Years)')
ax.set_ylabel('Autocorrelation')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=1)
plt.tight_layout()
save_chart('sunspots_acf')
plt.show()

print("ACF shows clear peaks at lags 11 and 22, confirming the solar cycle.")
# Out:
#   Saved: sunspots.pdf
#   Saved: sunspots_acf.pdf
# ACF shows clear peaks at lags 11 and 22, confirming the solar cycle.

# %%
# Step 1: Train/Validation/Test Split
print("\nSTEP 1: DATA SPLITTING")
print("="*60)

train_sun, val_sun, test_sun = time_series_split(sunspots, 0.70, 0.20, 0.10)

print(f"\nDate Ranges:")
print(f"  Training:   {train_sun['ds'].min().year} to {train_sun['ds'].max().year}")
print(f"  Validation: {val_sun['ds'].min().year} to {val_sun['ds'].max().year}")
print(f"  Test:       {test_sun['ds'].min().year} to {test_sun['ds'].max().year}")
# Out:
# STEP 1: DATA SPLITTING
# ============================================================
# Data Split (Total: 109 observations):
#   Training:     76 (69.7%)
#   Validation:   22 (20.2%)
#   Test:         11 (10.1%)
#
# Date Ranges:
#   Training:   1900 to 1975
#   Validation: 1976 to 1997
#   Test:       1998 to 2008

# %%
# Step 2: Add Fourier terms and select K
print("\nSTEP 2: MODEL SELECTION - Finding Optimal Number of Fourier Harmonics")
print("="*60)

def add_fourier_terms(df, period, K, start_idx=0):
    """Add K Fourier pairs (sin/cos) for given period"""
    result = df.copy()
    t = np.arange(start_idx, start_idx + len(df))
    for k in range(1, K + 1):
        result[f'sin_{k}'] = np.sin(2 * np.pi * k * t / period)
        result[f'cos_{k}'] = np.cos(2 * np.pi * k * t / period)
    return result

# Test K = 1, 2, 3, 4 Fourier pairs
results_K = {}

print("\nComparing Fourier harmonics K=1,2,3,4 on VALIDATION set:")
print("-" * 60)

for K in [1, 2, 3, 4]:
    # Add Fourier terms
    train_fourier = add_fourier_terms(train_sun, period=11, K=K, start_idx=0)
    val_fourier = add_fourier_terms(val_sun, period=11, K=K, start_idx=len(train_sun))
    
    exog_cols = [f'sin_{k}' for k in range(1, K+1)] + [f'cos_{k}' for k in range(1, K+1)]
    
    # Fit ARIMA(2,0,1) with Fourier regressors
    try:
        model = SARIMAX(train_fourier['y'], 
                       exog=train_fourier[exog_cols],
                       order=(2, 0, 1),
                       enforce_stationarity=False,
                       enforce_invertibility=False)
        res = model.fit(disp=False)
        
        # Forecast on validation
        forecast = res.get_forecast(steps=len(val_fourier), exog=val_fourier[exog_cols])
        val_pred = forecast.predicted_mean.values
        
        # Metrics
        rmse = np.sqrt(mean_squared_error(val_fourier['y'], val_pred))
        mae = mean_absolute_error(val_fourier['y'], val_pred)
        
        results_K[K] = {'AIC': res.aic, 'BIC': res.bic, 'RMSE': rmse, 'MAE': mae, 'model': res}
        print(f"K={K}: AIC={res.aic:8.2f}  BIC={res.bic:8.2f}  Val RMSE={rmse:6.2f}  Val MAE={mae:6.2f}")
    except Exception as e:
        print(f"K={K}: Failed - {e}")

# Select best K
best_K = min(results_K, key=lambda x: results_K[x]['RMSE'])
print(f"\n>>> BEST: K={best_K} Fourier harmonics (lowest validation RMSE)")
# Out:
# STEP 2: MODEL SELECTION - Finding Optimal Number of Fourier Harmonics
# ============================================================
#
# Comparing Fourier harmonics K=1,2,3,4 on VALIDATION set:
# ------------------------------------------------------------
# K=1: AIC=  665.92  BIC=  679.75  Val RMSE= 76.33  Val MAE= 60.92
# K=2: AIC=  668.00  BIC=  686.43  Val RMSE= 76.02  Val MAE= 61.08
# K=3: AIC=  671.82  BIC=  694.86  Val RMSE= 75.89  Val MAE= 60.98
# K=4: AIC=  674.53  BIC=  702.18  Val RMSE= 76.79  Val MAE= 62.11
#
# >>> BEST: K=3 Fourier harmonics (lowest validation RMSE)

# %%
# Step 3: Final Model - Refit on Train+Val, Evaluate on Test
print("\nSTEP 3: FINAL EVALUATION (Test Set)")
print("="*60)

# Combine training and validation
trainval_sun = pd.concat([train_sun, val_sun]).reset_index(drop=True)

# Add Fourier terms
trainval_fourier = add_fourier_terms(trainval_sun, period=11, K=best_K, start_idx=0)
test_fourier = add_fourier_terms(test_sun, period=11, K=best_K, start_idx=len(trainval_sun))

exog_cols = [f'sin_{k}' for k in range(1, best_K+1)] + [f'cos_{k}' for k in range(1, best_K+1)]

print(f"\nRefitting ARIMA(2,0,1) + {best_K} Fourier harmonics")
print(f"  Training+Validation: {len(trainval_fourier)} years")
print(f"  Test: {len(test_fourier)} years (HELD OUT until now!)\n")

# Fit final model
final_sun_model = SARIMAX(trainval_fourier['y'],
                          exog=trainval_fourier[exog_cols],
                          order=(2, 0, 1),
                          enforce_stationarity=False,
                          enforce_invertibility=False)
final_sun_results = final_sun_model.fit(disp=False)

# Forecast on test
test_forecast = final_sun_results.get_forecast(steps=len(test_fourier), exog=test_fourier[exog_cols])
test_pred = test_forecast.predicted_mean.values
test_ci = test_forecast.conf_int()

# Metrics
test_metrics = calc_metrics(test_fourier['y'], test_pred, "TEST SET")

print(f"\nModel Summary:")
print(final_sun_results.summary().tables[1])
# Out:
# STEP 3: FINAL EVALUATION (Test Set)
# ============================================================
#
# Refitting ARIMA(2,0,1) + 3 Fourier harmonics
#   Training+Validation: 98 years
#   Test: 11 years (HELD OUT until now!)
# TEST SET Metrics:
#   RMSE: 31.1041
#   MAE:  25.8328
#   MAPE: 124.34%
#
# Model Summary:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sin_1         35.7733      9.441      3.789      0.000      17.270      54.277
# sin_2          2.6770      3.997      0.670      0.503      -5.158      10.512
# sin_3          1.1911      2.017      0.590      0.555      -2.763       5.145
# cos_1        -24.5077     11.692     -2.096      0.036     -47.424      -1.592
# cos_2         -5.3911      3.958     -1.362      0.173     -13.149       2.366
# cos_3         -0.3320      2.042     -0.163      0.871      -4.333       3.670
# ar.L1          1.3668      0.206      6.637      0.000       0.963       1.770
# ar.L2         -0.4416      0.200     -2.204      0.028      -0.834      -0.049
# ma.L1          0.0031      0.245      0.013      0.990      -0.477       0.483
# sigma2       433.3717     68.759      6.303      0.000     298.607     568.136
# ==============================================================================
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Visualize final results - Generate chart matching slides

# Chart: Sunspot Forecast (sunspot_forecast.pdf)
fig, ax = plt.subplots(figsize=(10, 4.5))

# Training data
ax.plot(train_sun['ds'], train_sun['y'], color=COLORS['blue'], linewidth=1.5, label='Train (70%)')
ax.plot(val_sun['ds'], val_sun['y'], color=COLORS['purple'], linewidth=1.5, label='Val (20%)')

# Test actual
ax.plot(test_fourier['ds'], test_fourier['y'], color=COLORS['green'], linewidth=2, label='Test (10%)')

# Test forecast
ax.plot(test_fourier['ds'], test_pred, color=COLORS['red'], linewidth=2, linestyle='--', label='Forecast')

# Confidence interval
ax.fill_between(test_fourier['ds'], test_ci.iloc[:, 0], test_ci.iloc[:, 1],
                color=COLORS['red'], alpha=0.2)

# Mark splits
ax.axvline(x=val_sun['ds'].iloc[0], color='gray', linestyle='--', alpha=0.5)
ax.axvline(x=test_fourier['ds'].iloc[0], color='black', linestyle='--', alpha=0.7)

ax.set_title(f'Sunspot Forecast: ARIMA + Fourier (K={best_K}) | Train/Val/Test 70/20/10', fontweight='bold')
ax.set_xlabel('Year')
ax.set_ylabel('Sunspot Count')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=4, frameon=False)

plt.tight_layout()
save_chart('sunspot_forecast')
plt.show()

print("\n" + "="*60)
print("CASE STUDY 2 SUMMARY: Sunspot Cycles")
print("="*60)
print(f"Best Model: ARIMA(2,0,1) + {best_K} Fourier harmonics")
print(f"Test RMSE: {test_metrics['rmse']:.2f}")
print(f"Test MAPE: {test_metrics['mape']:.2f}%")
print("\nKey Insight: Fourier terms capture long seasonal patterns effectively!")
# Out:
#   Saved: sunspot_forecast.pdf
# ============================================================
# CASE STUDY 2 SUMMARY: Sunspot Cycles
# ============================================================
# Best Model: ARIMA(2,0,1) + 3 Fourier harmonics
# Test RMSE: 31.10
# Test MAPE: 124.34%
#
# Key Insight: Fourier terms capture long seasonal patterns effectively!

# %% [markdown]
# ---
# # Case Study 3: US Unemployment with Structural Break
#
# ## Objective
# Handle the COVID-19 structural break using Prophet's changepoint detection.
#
# ## Challenge
# - April 2020: Unemployment jumped from 3.5% to 14.7% (largest single-month increase ever)
# - Traditional ARIMA struggles with such extreme outliers
#
# ## Methodology
# 1. **Training (70%)**: Fit Prophet with changepoint detection
# 2. **Validation (20%)**: Tune changepoint_prior_scale
# 3. **Test (10%)**: Final evaluation

# %%
# Load Unemployment data
unemp = get_unemployment_data()

print("\n" + "="*60)
print("US UNEMPLOYMENT DATA OVERVIEW")
print("="*60)
print(f"Period: {unemp['ds'].min().strftime('%Y-%m')} to {unemp['ds'].max().strftime('%Y-%m')}")
print(f"Observations: {len(unemp)} months")
print(f"\nKey Statistics:")
print(f"  Pre-COVID Min (Feb 2020): {unemp[unemp['ds'] < '2020-03-01']['y'].min():.1f}%")
print(f"  COVID Peak (Apr 2020):    {unemp['y'].max():.1f}%")
print(f"  Latest:                   {unemp['y'].iloc[-1]:.1f}%")
print(f"\nStructural Break: March-April 2020")
# Out:
# US Unemployment: Loaded 181 months of REAL data from FRED
#
# ============================================================
# US UNEMPLOYMENT DATA OVERVIEW
# ============================================================
# Period: 2010-01 to 2025-01
# Observations: 181 months
#
# Key Statistics:
#   Pre-COVID Min (Feb 2020): 3.5%
#   COVID Peak (Apr 2020):    14.8%
#   Latest:                   4.0%
#
# Structural Break: March-April 2020

# %%
# Visualize the structural break - Generate charts matching slides

# Chart: Unemployment data overview (unemployment.pdf)
fig, axes = plt.subplots(2, 1, figsize=(10, 6))

# Main plot with COVID highlight
axes[0].plot(unemp['ds'], unemp['y'], color=COLORS['blue'], linewidth=1.5)
axes[0].axvspan(pd.Timestamp('2020-03-01'), pd.Timestamp('2020-05-01'),
                alpha=0.3, color=COLORS['red'], label='COVID-19 Shock')
axes[0].set_title('US Unemployment Rate: COVID-19 Structural Break', fontweight='bold')
axes[0].set_ylabel('Unemployment Rate (%)')
axes[0].legend(loc='upper right')

# Month-over-month change
unemp_change = unemp['y'].diff()
colors_bar = [COLORS['green'] if x < 0 else COLORS['red'] for x in unemp_change]
axes[1].bar(unemp['ds'], unemp_change, color=colors_bar, width=20, alpha=0.7)
axes[1].axhline(y=0, color='black', linewidth=0.5)
axes[1].set_title('Month-over-Month Change (pp)', fontweight='bold')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Change (pp)')

plt.tight_layout()
plt.subplots_adjust(hspace=0.3)
save_chart('unemployment')
plt.show()

# Chart: Unemployment ACF/PACF (unemployment_acf_pacf.pdf)
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
plot_acf(unemp['y'].dropna(), ax=axes[0], lags=24, alpha=0.05)
axes[0].set_title('ACF: Slow Decay (Non-stationary)', fontweight='bold')
axes[0].set_xlabel('Lag (Months)')
plot_pacf(unemp['y'].dropna(), ax=axes[1], lags=24, alpha=0.05)
axes[1].set_title('PACF: AR(1) + Seasonal', fontweight='bold')
axes[1].set_xlabel('Lag (Months)')
plt.tight_layout()
save_chart('unemployment_acf_pacf')
plt.show()

# Chart: Unemployment stationarity (unemployment_stationarity.pdf)
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
axes[0].plot(unemp['ds'], unemp['y'], color=COLORS['blue'], linewidth=1)
axes[0].set_title('Original Series (Non-stationary)', fontweight='bold')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Unemployment Rate (%)')
unemp_diff = unemp['y'].diff().dropna()
axes[1].plot(unemp['ds'].iloc[1:], unemp_diff, color=COLORS['green'], linewidth=1)
axes[1].axhline(y=0, color='black', linewidth=0.5, alpha=0.3)
axes[1].set_title('First Difference (Stationary)', fontweight='bold')
axes[1].set_xlabel('Date')
axes[1].set_ylabel('Change (pp)')
plt.tight_layout()
save_chart('unemployment_stationarity')
plt.show()

print("April 2020: +10.3 percentage points - largest monthly increase in history!")
# Out:
#   Saved: unemployment.pdf
#   Saved: unemployment_acf_pacf.pdf
#   Saved: unemployment_stationarity.pdf
# April 2020: +10.3 percentage points - largest monthly increase in history!

# %%
# Step 1: Train/Validation/Test Split
print("\nSTEP 1: DATA SPLITTING")
print("="*60)

train_unemp, val_unemp, test_unemp = time_series_split(unemp, 0.70, 0.20, 0.10)

print(f"\nDate Ranges:")
print(f"  Training:   {train_unemp['ds'].min().strftime('%Y-%m')} to {train_unemp['ds'].max().strftime('%Y-%m')}")
print(f"  Validation: {val_unemp['ds'].min().strftime('%Y-%m')} to {val_unemp['ds'].max().strftime('%Y-%m')}")
print(f"  Test:       {test_unemp['ds'].min().strftime('%Y-%m')} to {test_unemp['ds'].max().strftime('%Y-%m')}")

# Chart: Unemployment train/val/test split (unemployment_train_val_test.pdf)
fig, ax = plt.subplots(figsize=(10, 4.5))
ax.plot(train_unemp['ds'], train_unemp['y'], color=COLORS['blue'], linewidth=1.5, label='Train (70%)')
ax.plot(val_unemp['ds'], val_unemp['y'], color=COLORS['purple'], linewidth=1.5, label='Val (20%)')
ax.plot(test_unemp['ds'], test_unemp['y'], color=COLORS['green'], linewidth=2, label='Test (10%)')
ax.axvspan(pd.Timestamp('2020-03-01'), pd.Timestamp('2020-05-01'),
           alpha=0.2, color=COLORS['red'], label='COVID-19')
ax.axvline(x=val_unemp['ds'].iloc[0], color='gray', linestyle='--', alpha=0.5)
ax.axvline(x=test_unemp['ds'].iloc[0], color='black', linestyle='--', alpha=0.7)
ax.set_title('US Unemployment: Train/Val/Test Split (70/20/10)', fontweight='bold')
ax.set_xlabel('Date')
ax.set_ylabel('Unemployment Rate (%)')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=4, frameon=False)
plt.tight_layout()
save_chart('unemployment_train_val_test')
plt.show()
# Out:
# STEP 1: DATA SPLITTING
# ============================================================
# Data Split (Total: 181 observations):
#   Training:    126 (69.6%)
#   Validation:   36 (19.9%)
#   Test:         19 (10.5%)
#
# Date Ranges:
#   Training:   2010-01 to 2020-06
#   Validation: 2020-07 to 2023-06
#   Test:       2023-07 to 2025-01
#   Saved: unemployment_train_val_test.pdf

# %%
# Step 2: SARIMA Model Selection
print("\nSTEP 2A: SARIMA MODEL SELECTION")
print("="*60)
print("Testing SARIMA(p,d,q)(P,D,Q)_12 on VALIDATION set\n")

from itertools import product

# SARIMA grid search
p_values = [0, 1, 2]
d_values = [1]  # First difference for non-stationarity
q_values = [0, 1, 2]
P_values = [0, 1]
D_values = [0, 1]
Q_values = [0, 1]

sarima_results = []

print("Testing SARIMA models (this may take a moment)...")
for p, d, q, P, D, Q in product(p_values, d_values, q_values, P_values, D_values, Q_values):
    try:
        model = SARIMAX(train_unemp['y'], order=(p, d, q), 
                       seasonal_order=(P, D, Q, 12),
                       enforce_stationarity=False,
                       enforce_invertibility=False)
        results = model.fit(disp=False)
        
        # Forecast on validation
        forecast = results.get_forecast(steps=len(val_unemp))
        val_pred = forecast.predicted_mean.values
        
        rmse = np.sqrt(mean_squared_error(val_unemp['y'], val_pred))
        sarima_results.append({
            'order': (p, d, q),
            'seasonal': (P, D, Q, 12),
            'AIC': results.aic,
            'BIC': results.bic,
            'RMSE': rmse
        })
    except:
        pass

# Sort by validation RMSE
sarima_df = pd.DataFrame(sarima_results).sort_values('RMSE')
print("\nTop 5 SARIMA models by validation RMSE:")
print(sarima_df.head().to_string(index=False))

best_sarima = sarima_df.iloc[0]
best_order = best_sarima['order']
best_seasonal = best_sarima['seasonal']
print(f"\n>>> BEST: SARIMA{best_order}x{best_seasonal}")

# Chart: SARIMA Model Selection (sarima_model_selection.pdf)
fig, ax = plt.subplots(figsize=(10, 5))
top_models = sarima_df.head(10)
colors = [COLORS['green'] if i == 0 else COLORS['blue'] for i in range(len(top_models))]
bars = ax.barh(range(len(top_models)), top_models['RMSE'], color=colors, alpha=0.7)
ax.set_yticks(range(len(top_models)))
ax.set_yticklabels([f"SARIMA{r['order']}x{r['seasonal']}" for _, r in top_models.iterrows()], fontsize=9)
ax.set_xlabel('Validation RMSE')
ax.set_title('SARIMA Model Selection: Top 10 by Validation RMSE', fontweight='bold')
ax.invert_yaxis()
for i, (rmse, aic) in enumerate(zip(top_models['RMSE'], top_models['AIC'])):
    ax.text(rmse + 0.01, i, f'RMSE={rmse:.3f}, AIC={aic:.0f}', va='center', fontsize=8)
plt.tight_layout()
save_chart('sarima_model_selection')
plt.show()
# Out:
# STEP 2A: SARIMA MODEL SELECTION
# ============================================================
# Testing SARIMA(p,d,q)(P,D,Q)_12 on VALIDATION set
#
# Testing SARIMA models (this may take a moment)...
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /opt/anaconda3/lib/python3.13/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# Top 5 SARIMA models by validation RMSE:
#     order      seasonal        AIC        BIC     RMSE
# (1, 1, 1) (1, 0, 1, 12) 329.385947 342.933598 4.291989
# (1, 1, 1) (1, 0, 0, 12) 329.671522 340.545518 4.405978
# (0, 1, 0) (1, 0, 1, 12) 329.655726 337.811223 4.472643
# (1, 1, 0) (1, 0, 1, 12) 331.517918 342.391914 4.511895
# (0, 1, 0) (1, 0, 0, 12) 329.559203 335.013979 4.528010
#
# >>> BEST: SARIMA(1, 1, 1)x(1, 0, 1, 12)
#   Saved: sarima_model_selection.pdf

# %%
# Step 2B: SARIMA - Fit Final Model and Diagnostics
print("\nSTEP 2B: SARIMA FINAL MODEL")
print("="*60)

# Combine train+val for final model
trainval_unemp = pd.concat([train_unemp, val_unemp]).reset_index(drop=True)

print(f"Fitting SARIMA{best_order}x{best_seasonal} on Train+Val ({len(trainval_unemp)} months)")

# Fit final SARIMA model
final_sarima = SARIMAX(trainval_unemp['y'], order=best_order, 
                       seasonal_order=best_seasonal,
                       enforce_stationarity=False,
                       enforce_invertibility=False)
sarima_fit = final_sarima.fit(disp=False)

print("\nModel Parameters:")
print(sarima_fit.summary().tables[1])

# Chart: SARIMA Parameters (sarima_parameters.pdf)
fig, ax = plt.subplots(figsize=(10, 4))
params = sarima_fit.params[:-1]  # Exclude sigma2
conf_int = sarima_fit.conf_int().iloc[:-1]
y_pos = range(len(params))
ax.barh(y_pos, params.values, color=COLORS['blue'], alpha=0.7)
ax.errorbar(params.values, y_pos, 
            xerr=[params.values - conf_int.iloc[:, 0].values, 
                  conf_int.iloc[:, 1].values - params.values],
            fmt='none', color='black', capsize=3)
ax.axvline(x=0, color='black', linewidth=0.5)
ax.set_yticks(y_pos)
ax.set_yticklabels(params.index)
ax.set_xlabel('Coefficient Value')
ax.set_title(f'SARIMA{best_order}x{best_seasonal} Parameters with 95% CI', fontweight='bold')
plt.tight_layout()
save_chart('sarima_parameters')
plt.show()

# Chart: SARIMA Diagnostics (sarima_diagnostics.pdf)
fig = sarima_fit.plot_diagnostics(figsize=(10, 8))
plt.suptitle(f'SARIMA{best_order}x{best_seasonal} Residual Diagnostics', fontweight='bold', y=1.02)
plt.tight_layout()
save_chart('sarima_diagnostics')
plt.show()

# SARIMA Rolling Forecast on Test Set
print("\nSARIMA Rolling One-Step-Ahead Forecast on Test Set...")
sarima_test_pred = []
history = trainval_unemp['y'].values.tolist()

for t in range(len(test_unemp)):
    model = SARIMAX(history, order=best_order, seasonal_order=best_seasonal,
                   enforce_stationarity=False, enforce_invertibility=False)
    fit = model.fit(disp=False)
    forecast = fit.forecast(steps=1)
    sarima_test_pred.append(forecast[0])
    history.append(test_unemp['y'].iloc[t])

sarima_test_pred = np.array(sarima_test_pred)
sarima_rmse = np.sqrt(mean_squared_error(test_unemp['y'], sarima_test_pred))
sarima_mae = mean_absolute_error(test_unemp['y'], sarima_test_pred)

print(f"\nSARIMA Test Results:")
print(f"  RMSE: {sarima_rmse:.4f}")
print(f"  MAE:  {sarima_mae:.4f}")

# Chart: SARIMA Forecast (sarima_forecast.pdf)
fig, ax = plt.subplots(figsize=(10, 4.5))
ax.plot(train_unemp['ds'], train_unemp['y'], color=COLORS['blue'], linewidth=1.5, label='Train (70%)')
ax.plot(val_unemp['ds'], val_unemp['y'], color=COLORS['purple'], linewidth=1.5, label='Val (20%)')
ax.plot(test_unemp['ds'], test_unemp['y'], color=COLORS['green'], linewidth=2, label='Test (10%)')
ax.plot(test_unemp['ds'], sarima_test_pred, color=COLORS['red'], linewidth=2, 
        linestyle='--', label='SARIMA Forecast')
ax.axvline(x=val_unemp['ds'].iloc[0], color='gray', linestyle='--', alpha=0.5)
ax.axvline(x=test_unemp['ds'].iloc[0], color='black', linestyle='--', alpha=0.7)
ax.text(0.02, 0.95, f'Test RMSE = {sarima_rmse:.2f}', transform=ax.transAxes,
        fontsize=11, va='top', fontweight='bold', color=COLORS['red'],
        bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
ax.set_title(f'SARIMA{best_order}x{best_seasonal}: Rolling One-Step Forecast', fontweight='bold')
ax.set_xlabel('Date')
ax.set_ylabel('Unemployment Rate (%)')
ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=5, frameon=False, fontsize=9)
plt.tight_layout()
plt.subplots_adjust(bottom=0.18)
save_chart('sarima_forecast')
plt.show()
# Out:
# STEP 2B: SARIMA FINAL MODEL
# ============================================================
# Fitting SARIMA(1, 1, 1)x(1, 0, 1, 12) on Train+Val (162 months)
# Model Parameters:
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.8423      0.208      4.042      0.000       0.434       1.251
# ma.L1         -0.9540      0.197     -4.835      0.000      -1.341      -0.567
# ar.S.L12       0.0326      4.595      0.007      0.994      -8.974       9.039
# ma.S.L12      -0.0113      4.609     -0.002      0.998      -9.044       9.022
# sigma2         0.8122      0.061     13.351      0.000       0.693       0.931
# ==============================================================================
#   Saved: sarima_parameters.pdf
#   Saved: sarima_diagnostics.pdf
# SARIMA Rolling One-Step-Ahead Forecast on Test Set...
# SARIMA Test Results:
#   RMSE: 0.1162
#   MAE:  0.0981
#   Saved: sarima_forecast.pdf

# %%
# Step 2C: Prophet Model Selection and Forecast
print("\nSTEP 2C: PROPHET MODEL SELECTION")
print("="*60)

if HAS_PROPHET:
    # Test different changepoint_prior_scale values
    scales_to_test = [0.01, 0.05, 0.1, 0.3, 0.5]
    results_prophet = {}
    
    print("Comparing changepoint_prior_scale on VALIDATION set:")
    print("(Higher scale = more flexible trend, can overfit)")
    print("(Lower scale = smoother trend, may underfit)\n")
    
    for scale in scales_to_test:
        try:
            model = Prophet(
                changepoint_prior_scale=scale,
                yearly_seasonality=True,
                weekly_seasonality=False,
                daily_seasonality=False
            )
            model.fit(train_unemp)
            
            future_val = model.make_future_dataframe(periods=len(val_unemp), freq='MS')
            forecast_val = model.predict(future_val)
            val_pred = forecast_val['yhat'].iloc[-len(val_unemp):].values
            
            rmse = np.sqrt(mean_squared_error(val_unemp['y'], val_pred))
            results_prophet[scale] = {'RMSE': rmse, 'model': model}
            print(f"scale={scale:4.2f}: Val RMSE={rmse:.4f}")
        except Exception as e:
            print(f"scale={scale:4.2f}: Failed - {e}")
    
    best_scale = min(results_prophet, key=lambda x: results_prophet[x]['RMSE'])
    print(f"\n>>> BEST: changepoint_prior_scale={best_scale}")
    
    # Fit final Prophet model on train+val
    print(f"\nFitting Prophet on Train+Val ({len(trainval_unemp)} months)...")
    final_prophet = Prophet(
        changepoint_prior_scale=best_scale,
        yearly_seasonality=True,
        weekly_seasonality=False,
        daily_seasonality=False
    )
    final_prophet.fit(trainval_unemp)
    
    # Forecast on test
    future_test = final_prophet.make_future_dataframe(periods=len(test_unemp), freq='MS')
    forecast_test = final_prophet.predict(future_test)
    prophet_test_pred = forecast_test['yhat'].iloc[-len(test_unemp):].values
    prophet_lower = forecast_test['yhat_lower'].iloc[-len(test_unemp):].values
    prophet_upper = forecast_test['yhat_upper'].iloc[-len(test_unemp):].values
    
    prophet_rmse = np.sqrt(mean_squared_error(test_unemp['y'], prophet_test_pred))
    prophet_mae = mean_absolute_error(test_unemp['y'], prophet_test_pred)
    
    print(f"\nProphet Test Results:")
    print(f"  RMSE: {prophet_rmse:.4f}")
    print(f"  MAE:  {prophet_mae:.4f}")
    
    # Chart: Prophet Forecast (unemployment_forecast.pdf)
    fig, ax = plt.subplots(figsize=(10, 4.5))
    ax.plot(train_unemp['ds'], train_unemp['y'], color=COLORS['blue'], linewidth=1.5, label='Train (70%)')
    ax.plot(val_unemp['ds'], val_unemp['y'], color=COLORS['purple'], linewidth=1.5, label='Val (20%)')
    ax.plot(test_unemp['ds'], test_unemp['y'], color=COLORS['green'], linewidth=2, label='Test (10%)')
    ax.plot(test_unemp['ds'], prophet_test_pred, color=COLORS['orange'], linewidth=2, 
            linestyle='--', label='Prophet Forecast')
    ax.fill_between(test_unemp['ds'], prophet_lower, prophet_upper, color=COLORS['orange'], alpha=0.15)
    ax.axvline(x=val_unemp['ds'].iloc[0], color='gray', linestyle='--', alpha=0.5)
    ax.axvline(x=test_unemp['ds'].iloc[0], color='black', linestyle='--', alpha=0.7)
    ax.text(0.02, 0.95, f'Test RMSE = {prophet_rmse:.2f}', transform=ax.transAxes,
            fontsize=11, va='top', fontweight='bold', color=COLORS['orange'],
            bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    ax.set_title('Prophet Forecast: Adapts via Changepoint Detection', fontweight='bold')
    ax.set_xlabel('Date')
    ax.set_ylabel('Unemployment Rate (%)')
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.12), ncol=5, frameon=False, fontsize=9)
    plt.tight_layout()
    plt.subplots_adjust(bottom=0.18)
    save_chart('unemployment_forecast')
    plt.show()
else:
    print("Prophet not available - skipping")
    prophet_rmse = None
    prophet_test_pred = None
# Out:
# STEP 2C: PROPHET MODEL SELECTION
# ============================================================
# Comparing changepoint_prior_scale on VALIDATION set:
# (Higher scale = more flexible trend, can overfit)
# (Lower scale = smoother trend, may underfit)
# 09:37:46 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:46 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:46 - cmdstanpy - ERROR - Chain [1] error: code '1' Operation not permitted
# Optimization terminated abnormally. Falling back to Newton.
# 09:37:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] start processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] done processing
# 09:37:47 - cmdstanpy - INFO - Chain [1] start processing
# scale=0.01: Val RMSE=2.7708
# scale=0.05: Val RMSE=1.9103
# scale=0.10: Val RMSE=3.1222
# scale=0.30: Val RMSE=4.4419
# scale=0.50: Val RMSE=5.0129
#
# >>> BEST: changepoint_prior_scale=0.05
#
# Fitting Prophet on Train+Val (162 months)...
# 09:37:47 - cmdstanpy - INFO - Chain [1] done processing
# Prophet Test Results:
#   RMSE: 0.5773
#   MAE:  0.4650
#   Saved: unemployment_forecast.pdf

# %%
# Step 3: SARIMA vs Prophet Comparison
print("\nSTEP 3: SARIMA vs PROPHET COMPARISON")
print("="*60)

# Chart: SARIMA vs Prophet Comparison (prophet_vs_sarima_unemployment.pdf)
fig, axes = plt.subplots(1, 2, figsize=(12, 4.5))

# SARIMA subplot
axes[0].plot(test_unemp['ds'], test_unemp['y'], color=COLORS['green'], linewidth=2, label='Actual')
axes[0].plot(test_unemp['ds'], sarima_test_pred, color=COLORS['red'], linewidth=2, 
             linestyle='--', label='SARIMA')
axes[0].set_title(f'SARIMA: Test RMSE = {sarima_rmse:.2f}', fontweight='bold')
axes[0].set_xlabel('Date')
axes[0].set_ylabel('Unemployment Rate (%)')
axes[0].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2, frameon=False)

# Prophet subplot
if HAS_PROPHET and prophet_test_pred is not None:
    axes[1].plot(test_unemp['ds'], test_unemp['y'], color=COLORS['green'], linewidth=2, label='Actual')
    axes[1].plot(test_unemp['ds'], prophet_test_pred, color=COLORS['orange'], linewidth=2, 
                 linestyle='--', label='Prophet')
    axes[1].set_title(f'Prophet: Test RMSE = {prophet_rmse:.2f}', fontweight='bold')
    axes[1].set_xlabel('Date')
    axes[1].set_ylabel('Unemployment Rate (%)')
    axes[1].legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2, frameon=False)
else:
    axes[1].text(0.5, 0.5, 'Prophet not available', ha='center', va='center', fontsize=12)
    axes[1].set_title('Prophet: N/A', fontweight='bold')

plt.tight_layout()
plt.subplots_adjust(bottom=0.2)
save_chart('prophet_vs_sarima_unemployment')
plt.show()

# Summary
print("\n" + "="*60)
print("CASE STUDY 3 SUMMARY: Unemployment Forecasting")
print("="*60)
print(f"\nSARIMA{best_order}x{best_seasonal}:")
print(f"  Test RMSE: {sarima_rmse:.4f}")
print(f"  Test MAE:  {sarima_mae:.4f}")

if HAS_PROPHET and prophet_rmse is not None:
    print(f"\nProphet (scale={best_scale}):")
    print(f"  Test RMSE: {prophet_rmse:.4f}")
    print(f"  Test MAE:  {prophet_mae:.4f}")
    
    if sarima_rmse < prophet_rmse:
        print(f"\n>>> SARIMA wins by {prophet_rmse - sarima_rmse:.4f} RMSE")
    else:
        print(f"\n>>> Prophet wins by {sarima_rmse - prophet_rmse:.4f} RMSE")

print("\nKey Insights:")
print("- SARIMA captures seasonal patterns systematically")
print("- Prophet adapts to structural breaks via changepoints")
print("- Both methods have comparable performance on this data")
# Out:
# STEP 3: SARIMA vs PROPHET COMPARISON
# ============================================================
#   Saved: prophet_vs_sarima_unemployment.pdf
# ============================================================
# CASE STUDY 3 SUMMARY: Unemployment Forecasting
# ============================================================
#
# SARIMA(1, 1, 1)x(1, 0, 1, 12):
#   Test RMSE: 0.1162
#   Test MAE:  0.0981
#
# Prophet (scale=0.05):
#   Test RMSE: 0.5773
#   Test MAE:  0.4650
#
# >>> SARIMA wins by 0.4611 RMSE
#
# Key Insights:
# - SARIMA captures seasonal patterns systematically
# - Prophet adapts to structural breaks via changepoints
# - Both methods have comparable performance on this data

# %% [markdown]
# ---
# # Case Study 4: Multivariate Analysis (VAR Model)
#
# ## Objective
# Model the relationships between multiple economic variables using Vector Autoregression (VAR).
#
# ## Variables
# - **GDP Growth** (quarterly, YoY %)
# - **Unemployment Rate** (%)
# - **Inflation** (CPI, YoY %)
# - **Federal Funds Rate** (%)
#
# ## Why VAR?
# - Captures **dynamic interdependencies** between multiple time series
# - Each variable is regressed on its own lags AND lags of all other variables
# - Enables **Granger causality** testing and **impulse response** analysis
#
# ## Methodology
# 1. **Training (70%)**: Fit VAR model
# 2. **Validation (20%)**: Select optimal lag order
# 3. **Test (10%)**: Multivariate forecast evaluation

# %%
# Load multivariate economic data
econ_data = get_multivariate_economic_data()

print("\n" + "="*60)
print("MULTIVARIATE ECONOMIC DATA OVERVIEW")
print("="*60)
print(f"Period: {econ_data.index.min().strftime('%Y-Q%q')} to {econ_data.index.max().strftime('%Y-Q%q')}")
print(f"Observations: {len(econ_data)} quarters")
print(f"\nVariables:")
for col in econ_data.columns:
    print(f"  {col:15s}: Mean={econ_data[col].mean():6.2f}, Std={econ_data[col].std():5.2f}")

print("\nCorrelation Matrix:")
print(econ_data.corr().round(2))
# Out:
# Economic Data: Loaded 97 quarters of REAL data from FRED
#   Variables: GDP Growth, Unemployment, Inflation, Fed Funds Rate
#
# ============================================================
# MULTIVARIATE ECONOMIC DATA OVERVIEW
# ============================================================
# Period: 2001-Qq to 2025-Qq
# Observations: 97 quarters
#
# Variables:
#   gdp_growth     : Mean=  2.15, Std= 2.12
#   unemployment   : Mean=  5.75, Std= 1.96
#   inflation      : Mean=  2.54, Std= 1.80
#   fed_rate       : Mean=  1.77, Std= 1.87
#
# Correlation Matrix:
#               gdp_growth  unemployment  inflation  fed_rate
# gdp_growth          1.00         -0.46       0.42      0.11
# unemployment       -0.46          1.00      -0.40     -0.59
# inflation           0.42         -0.40       1.00      0.28
# fed_rate            0.11         -0.59       0.28      1.00

# %%
# Visualize all variables - Generate chart matching slides

# Chart: Economic Variables (economic_vars.pdf)
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

variables = ['gdp_growth', 'unemployment', 'inflation', 'fed_rate']
titles = ['GDP Growth (YoY %)', 'Unemployment Rate (%)', 'Inflation (CPI YoY %)', 'Fed Funds Rate (%)']
colors = [COLORS['blue'], COLORS['red'], COLORS['green'], COLORS['orange']]

for ax, var, title, color in zip(axes.flat, variables, titles, colors):
    ax.plot(econ_data.index, econ_data[var], color=color, linewidth=1)
    ax.axhline(y=0, color='black', linewidth=0.5, alpha=0.3)
    ax.axvspan(pd.Timestamp('2008-06-01'), pd.Timestamp('2009-06-01'),
               alpha=0.2, color='gray')
    ax.axvspan(pd.Timestamp('2020-01-01'), pd.Timestamp('2020-06-01'),
               alpha=0.2, color='red')
    ax.set_title(title, fontweight='bold')
    ax.set_xlabel('Date')

plt.tight_layout()
save_chart('economic_vars')
plt.show()

print("Key Observations:")
print("- GDP and Unemployment are negatively correlated (Okun's Law)")
print("- Fed Rate responds to inflation (Taylor Rule)")
print("- All variables affected by 2008 crisis and COVID")
# Out:
#   Saved: economic_vars.pdf
# Key Observations:
# - GDP and Unemployment are negatively correlated (Okun's Law)
# - Fed Rate responds to inflation (Taylor Rule)
# - All variables affected by 2008 crisis and COVID

# %%
# Step 1: Stationarity Testing
print("\nSTEP 1: STATIONARITY TESTING")
print("="*60)
print("VAR requires all variables to be stationary.\n")

for var in econ_data.columns:
    adf_result = adfuller(econ_data[var].dropna(), autolag='AIC')
    status = "STATIONARY" if adf_result[1] < 0.05 else "NON-STATIONARY"
    print(f"{var:15s}: ADF p-value={adf_result[1]:.4f} -> {status}")

print("\nNote: Some variables may need differencing for strict stationarity.")
print("For this example, we proceed with levels (common in macroeconomics).")
# Out:
# STEP 1: STATIONARITY TESTING
# ============================================================
# VAR requires all variables to be stationary.
#
# gdp_growth     : ADF p-value=0.0113 -> STATIONARY
# unemployment   : ADF p-value=0.0558 -> NON-STATIONARY
# inflation      : ADF p-value=0.1456 -> NON-STATIONARY
# fed_rate       : ADF p-value=0.0214 -> STATIONARY
#
# Note: Some variables may need differencing for strict stationarity.
# For this example, we proceed with levels (common in macroeconomics).

# %%
# Step 2: Train/Validation/Test Split
print("\nSTEP 2: DATA SPLITTING")
print("="*60)

n = len(econ_data)
train_end = int(n * 0.70)
val_end = int(n * 0.90)  # 70% + 20% = 90%

train_econ = econ_data.iloc[:train_end]
val_econ = econ_data.iloc[train_end:val_end]
test_econ = econ_data.iloc[val_end:]

print(f"Data Split (Total: {n} quarters):")
print(f"  Training:   {len(train_econ):3d} quarters ({100*len(train_econ)/n:.0f}%) - {train_econ.index.min().strftime('%Y-Q%q')} to {train_econ.index.max().strftime('%Y-Q%q')}")
print(f"  Validation: {len(val_econ):3d} quarters ({100*len(val_econ)/n:.0f}%) - {val_econ.index.min().strftime('%Y-Q%q')} to {val_econ.index.max().strftime('%Y-Q%q')}")
print(f"  Test:       {len(test_econ):3d} quarters ({100*len(test_econ)/n:.0f}%) - {test_econ.index.min().strftime('%Y-Q%q')} to {test_econ.index.max().strftime('%Y-Q%q')}")
# Out:
# STEP 2: DATA SPLITTING
# ============================================================
# Data Split (Total: 97 quarters):
#   Training:    67 quarters (69%) - 2001-Qq to 2017-Qq
#   Validation:  20 quarters (21%) - 2017-Qq to 2022-Qq
#   Test:        10 quarters (10%) - 2022-Qq to 2025-Qq

# %%
# Step 3: Model Selection - Find optimal lag order
print("\nSTEP 3: MODEL SELECTION - Finding Optimal VAR Lag Order")
print("="*60)

# Fit VAR to find optimal lag using information criteria
var_model = VAR(train_econ)
lag_selection = var_model.select_order(maxlags=8)

print("\nInformation Criteria for Different Lag Orders:")
print(lag_selection.summary())

# Use BIC-selected lag (tends to be more parsimonious)
optimal_lag = lag_selection.bic
print(f"\n>>> Selected lag order (BIC): {optimal_lag}")
# Out:
# STEP 3: MODEL SELECTION - Finding Optimal VAR Lag Order
# ============================================================
#
# Information Criteria for Different Lag Orders:
#  VAR Order Selection (* highlights the minimums)
# =================================================
#       AIC         BIC         FPE         HQIC
# -------------------------------------------------
# 0       2.930       3.071       18.73       2.985
# 1      -5.674      -4.970    0.003440      -5.399
# 2      -6.642     -5.375*    0.001317      -6.147
# 3      -6.660      -4.829    0.001319      -5.945
# 4      -7.119      -4.724   0.0008659      -6.184
# 5      -7.363      -4.405  0.0007226*     -6.208*
# 6      -7.339      -3.818   0.0008160      -5.965
# 7      -7.513      -3.428   0.0007924      -5.918
# 8     -7.784*      -3.136   0.0007439      -5.969
# -------------------------------------------------
#
# >>> Selected lag order (BIC): 2

# %%
# Validate lag selection on validation set
print("\nValidating lag selection on VALIDATION set:")
print("-" * 60)

results_var = {}

for lag in range(1, 6):
    try:
        # Fit on training
        model = VAR(train_econ)
        fitted = model.fit(lag)
        
        # Forecast validation period
        forecast = fitted.forecast(train_econ.values[-lag:], steps=len(val_econ))
        
        # Calculate RMSE for each variable
        rmse_total = 0
        for i, var in enumerate(econ_data.columns):
            rmse = np.sqrt(mean_squared_error(val_econ[var], forecast[:, i]))
            rmse_total += rmse
        
        results_var[lag] = {'RMSE': rmse_total / len(econ_data.columns), 'model': fitted}
        print(f"Lag={lag}: Avg RMSE={rmse_total/len(econ_data.columns):.4f}")
    except Exception as e:
        print(f"Lag={lag}: Failed - {e}")

best_lag = min(results_var, key=lambda x: results_var[x]['RMSE'])
print(f"\n>>> BEST: Lag={best_lag} (lowest validation RMSE)")
# Out:
# Validating lag selection on VALIDATION set:
# ------------------------------------------------------------
# Lag=1: Avg RMSE=2.5264
# Lag=2: Avg RMSE=2.6118
# Lag=3: Avg RMSE=2.7624
# Lag=4: Avg RMSE=2.7289
# Lag=5: Avg RMSE=2.7418
#
# >>> BEST: Lag=1 (lowest validation RMSE)

# %%
# Step 4: Final Model - Refit on Train+Val, Evaluate on Test
print("\nSTEP 4: FINAL EVALUATION (Test Set)")
print("="*60)

# Combine training and validation
trainval_econ = pd.concat([train_econ, val_econ])

print(f"\nRefitting VAR({best_lag}) on Training+Validation data")
print(f"  Training+Validation: {len(trainval_econ)} quarters")
print(f"  Test: {len(test_econ)} quarters (HELD OUT until now!)\n")

# Fit final model
final_var = VAR(trainval_econ)
final_var_fitted = final_var.fit(best_lag)

# Forecast test period
test_forecast = final_var_fitted.forecast(trainval_econ.values[-best_lag:], steps=len(test_econ))

# Calculate metrics for each variable
print("TEST SET RESULTS:")
print("-" * 60)
test_var_metrics = {}
for i, var in enumerate(econ_data.columns):
    metrics = calc_metrics(test_econ[var], test_forecast[:, i], f"{var}")
    test_var_metrics[var] = metrics
# Out:
# STEP 4: FINAL EVALUATION (Test Set)
# ============================================================
#
# Refitting VAR(1) on Training+Validation data
#   Training+Validation: 87 quarters
#   Test: 10 quarters (HELD OUT until now!)
#
# TEST SET RESULTS:
# ------------------------------------------------------------
#
# gdp_growth Metrics:
#   RMSE: 1.3298
#   MAE:  1.2243
#   MAPE: 44.98%
#
# unemployment Metrics:
#   RMSE: 0.6369
#   MAE:  0.5599
#   MAPE: 14.33%
#
# inflation Metrics:
#   RMSE: 1.5579
#   MAE:  1.4480
#   MAPE: 44.76%
#
# fed_rate Metrics:
#   RMSE: 2.5889
#   MAE:  2.5381
#   MAPE: 51.58%

# %%
# Granger Causality Analysis
print("\nGRANGER CAUSALITY ANALYSIS")
print("="*60)
print("Testing if one variable helps predict another (beyond its own history)\n")

variables = econ_data.columns.tolist()
granger_results = pd.DataFrame(index=variables, columns=variables)

for cause in variables:
    for effect in variables:
        if cause != effect:
            try:
                test_data = trainval_econ[[effect, cause]]
                result = grangercausalitytests(test_data, maxlag=best_lag, verbose=False)
                # Get p-value from F-test at optimal lag
                p_value = result[best_lag][0]['ssr_ftest'][1]
                granger_results.loc[cause, effect] = f"{p_value:.3f}"
            except:
                granger_results.loc[cause, effect] = "N/A"
        else:
            granger_results.loc[cause, effect] = "-"

print("Granger Causality p-values (row CAUSES column):")
print("(p < 0.05 indicates significant Granger causality)\n")
print(granger_results)

print("\nInterpretation:")
print("- Low p-values suggest the ROW variable Granger-causes the COLUMN variable")
print("- Example: If gdp_growth -> unemployment has p < 0.05,")
print("  GDP growth helps predict future unemployment.")
# Out:
# GRANGER CAUSALITY ANALYSIS
# ============================================================
# Testing if one variable helps predict another (beyond its own history)
#
# Granger Causality p-values (row CAUSES column):
# (p < 0.05 indicates significant Granger causality)
#
#              gdp_growth unemployment inflation fed_rate
# gdp_growth            -        0.234     0.324    0.027
# unemployment      0.228            -     0.953    0.194
# inflation         0.798        0.143         -    0.032
# fed_rate          0.366        0.756     0.605        -
#
# Interpretation:
# - Low p-values suggest the ROW variable Granger-causes the COLUMN variable
# - Example: If gdp_growth -> unemployment has p < 0.05,
#   GDP growth helps predict future unemployment.

# %%
# Visualize VAR forecasts - Generate chart matching slides

# Chart: VAR Forecast (var_forecast.pdf)
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

for ax, (i, var) in zip(axes.flat, enumerate(econ_data.columns)):
    # Historical
    ax.plot(trainval_econ.index, trainval_econ[var], 
            color=COLORS['blue'], linewidth=1, label='Train+Val')
    # Test actual
    ax.plot(test_econ.index, test_econ[var], 
            color=COLORS['green'], linewidth=2, label='Test Actual')
    # Forecast
    ax.plot(test_econ.index, test_forecast[:, i], 
            color=COLORS['red'], linewidth=2, linestyle='--', 
            label=f'Forecast (RMSE={test_var_metrics[var]["rmse"]:.2f})')
    ax.axvline(x=trainval_econ.index[-1], color='black', linestyle=':', alpha=0.7)
    ax.set_title(var.replace('_', ' ').title(), fontweight='bold')
    ax.legend(loc='upper center', bbox_to_anchor=(0.5, -0.15), ncol=2, fontsize=9)

plt.tight_layout()
plt.subplots_adjust(hspace=0.4)
save_chart('var_forecast')
plt.show()
# Out:
#   Saved: var_forecast.pdf

# %%
# Impulse Response Functions - Generate charts matching slides
print("\nIMPULSE RESPONSE FUNCTIONS")
print("="*60)
print("How does a shock to one variable affect others over time?\n")

irf = final_var_fitted.irf(periods=12)

# Chart 1: IRF to GDP Shock (irf_gdp_shock.pdf)
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
shock_var = 'gdp_growth'
shock_idx = list(econ_data.columns).index(shock_var)

for ax, (i, response_var) in zip(axes.flat, enumerate(econ_data.columns)):
    irf_values = irf.irfs[:, i, shock_idx]
    ax.plot(range(len(irf_values)), irf_values, color=COLORS['purple'], linewidth=2)
    ax.axhline(y=0, color='black', linewidth=0.5, alpha=0.5)
    ax.fill_between(range(len(irf_values)), 
                   irf.irfs[:, i, shock_idx] - 1.96 * irf.stderr()[:, i, shock_idx],
                   irf.irfs[:, i, shock_idx] + 1.96 * irf.stderr()[:, i, shock_idx],
                   alpha=0.2, color=COLORS['purple'])
    ax.set_title(f'Response of {response_var.replace("_", " ").title()} to GDP Shock', fontweight='bold')
    ax.set_xlabel('Quarters')
    ax.set_ylabel('Response')

plt.tight_layout()
save_chart('irf_gdp_shock')
plt.show()

# Chart 2: IRF to Fed Rate Shock (irf_fed_shock.pdf)
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
shock_var = 'fed_rate'
shock_idx = list(econ_data.columns).index(shock_var)

for ax, (i, response_var) in zip(axes.flat, enumerate(econ_data.columns)):
    irf_values = irf.irfs[:, i, shock_idx]
    ax.plot(range(len(irf_values)), irf_values, color=COLORS['orange'], linewidth=2)
    ax.axhline(y=0, color='black', linewidth=0.5, alpha=0.5)
    ax.fill_between(range(len(irf_values)), 
                   irf.irfs[:, i, shock_idx] - 1.96 * irf.stderr()[:, i, shock_idx],
                   irf.irfs[:, i, shock_idx] + 1.96 * irf.stderr()[:, i, shock_idx],
                   alpha=0.2, color=COLORS['orange'])
    ax.set_title(f'Response of {response_var.replace("_", " ").title()} to Fed Rate Shock', fontweight='bold')
    ax.set_xlabel('Quarters')
    ax.set_ylabel('Response')

plt.tight_layout()
save_chart('irf_fed_shock')
plt.show()

# Chart 3: IRF to Unemployment Shock (irf_unemp_shock.pdf)
fig, axes = plt.subplots(2, 2, figsize=(12, 8))
shock_var = 'unemployment'
shock_idx = list(econ_data.columns).index(shock_var)

for ax, (i, response_var) in zip(axes.flat, enumerate(econ_data.columns)):
    irf_values = irf.irfs[:, i, shock_idx]
    ax.plot(range(len(irf_values)), irf_values, color=COLORS['red'], linewidth=2)
    ax.axhline(y=0, color='black', linewidth=0.5, alpha=0.5)
    ax.fill_between(range(len(irf_values)), 
                   irf.irfs[:, i, shock_idx] - 1.96 * irf.stderr()[:, i, shock_idx],
                   irf.irfs[:, i, shock_idx] + 1.96 * irf.stderr()[:, i, shock_idx],
                   alpha=0.2, color=COLORS['red'])
    ax.set_title(f'Response of {response_var.replace("_", " ").title()} to Unemployment Shock', fontweight='bold')
    ax.set_xlabel('Quarters')
    ax.set_ylabel('Response')

plt.tight_layout()
save_chart('irf_unemp_shock')
plt.show()

print("Interpretation:")
print("- Positive GDP shock typically DECREASES unemployment (Okun's Law)")
print("- Positive GDP shock may INCREASE inflation (demand-pull)")
print("- Fed responds by RAISING rates to control inflation (Taylor Rule)")
# Out:
# IMPULSE RESPONSE FUNCTIONS
# ============================================================
# How does a shock to one variable affect others over time?
#   Saved: irf_gdp_shock.pdf
#   Saved: irf_fed_shock.pdf
#   Saved: irf_unemp_shock.pdf
# Interpretation:
# - Positive GDP shock typically DECREASES unemployment (Okun's Law)
# - Positive GDP shock may INCREASE inflation (demand-pull)
# - Fed responds by RAISING rates to control inflation (Taylor Rule)

# %%
print("\n" + "="*60)
print("CASE STUDY 4 SUMMARY: Multivariate VAR Analysis")
print("="*60)
print(f"Model: VAR({best_lag})")
print(f"Variables: GDP Growth, Unemployment, Inflation, Fed Rate")
print(f"\nTest Set Performance:")
for var, metrics in test_var_metrics.items():
    print(f"  {var:15s}: RMSE={metrics['rmse']:.4f}, MAE={metrics['mae']:.4f}")
print("\nKey Insights:")
print("- VAR captures dynamic relationships between economic variables")
print("- Granger causality reveals which variables lead/lag others")
print("- Impulse responses show how shocks propagate through the system")
# Out:
# ============================================================
# CASE STUDY 4 SUMMARY: Multivariate VAR Analysis
# ============================================================
# Model: VAR(1)
# Variables: GDP Growth, Unemployment, Inflation, Fed Rate
#
# Test Set Performance:
#   gdp_growth     : RMSE=1.3298, MAE=1.2243
#   unemployment   : RMSE=0.6369, MAE=0.5599
#   inflation      : RMSE=1.5579, MAE=1.4480
#   fed_rate       : RMSE=2.5889, MAE=2.5381
#
# Key Insights:
# - VAR captures dynamic relationships between economic variables
# - Granger causality reveals which variables lead/lag others
# - Impulse responses show how shocks propagate through the system

# %% [markdown]
# ---
# # Summary: Complete Methodology
#
# ## Train/Validation/Test Framework (70/20/10)
#
# | Step | Purpose | Data Used |
# |------|---------|----------|
# | 1. Training | Estimate model parameters | 70% of data |
# | 2. Validation | Select hyperparameters, compare models | 20% of data |
# | 3. Test | Final unbiased evaluation | 10% of data (held out!) |
#
# ## Model Selection Summary
#
# | Case Study | Data Type | Best Model | Key Feature |
# |------------|-----------|------------|-------------|
# | Bitcoin | Financial | GARCH | Volatility clustering |
# | Sunspots | Long seasonal | ARIMA + Fourier | 11-year cycle |
# | Unemployment | Structural break | Prophet | Changepoint detection |
# | Economic | Multivariate | VAR | Cross-variable dynamics |

# %%
print("""
╔══════════════════════════════════════════════════════════════════════╗
║                    CHAPTER 10: KEY TAKEAWAYS                         ║
╠══════════════════════════════════════════════════════════════════════╣
║                                                                      ║
║  1. PROPER VALIDATION METHODOLOGY                                    ║
║     - NEVER peek at test data during model selection                 ║
║     - Use validation set for hyperparameter tuning                   ║
║     - Test set gives unbiased final performance estimate             ║
║                                                                      ║
║  2. MATCH MODEL TO DATA CHARACTERISTICS                              ║
║     - Financial data → GARCH for volatility                          ║
║     - Long seasonality → Fourier terms                               ║
║     - Structural breaks → Prophet/changepoints                       ║
║     - Multiple related series → VAR                                  ║
║                                                                      ║
║  3. INTERPRET RESULTS CAREFULLY                                      ║
║     - GARCH: Focus on volatility, not mean prediction                ║
║     - Granger causality ≠ true causality                             ║
║     - Confidence intervals matter for decision-making                ║
║                                                                      ║
║  4. PRACTICAL CONSIDERATIONS                                         ║
║     - Simple models often outperform complex ones                    ║
║     - Out-of-sample performance is what matters                      ║
║     - Always visualize data and residuals                            ║
║                                                                      ║
╚══════════════════════════════════════════════════════════════════════╝
""")
# Out:
# ╔══════════════════════════════════════════════════════════════════════╗
# ║                    CHAPTER 10: KEY TAKEAWAYS                         ║
# ╠══════════════════════════════════════════════════════════════════════╣
# ║                                                                      ║
# ║  1. PROPER VALIDATION METHODOLOGY                                    ║
# ║     - NEVER peek at test data during model selection                 ║
# ║     - Use validation set for hyperparameter tuning                   ║
# ║     - Test set gives unbiased final performance estimate             ║
# ║                                                                      ║
# ║  2. MATCH MODEL TO DATA CHARACTERISTICS                              ║
# ║     - Financial data → GARCH for volatility                          ║
# ║     - Long seasonality → Fourier terms                               ║
# ║     - Structural breaks → Prophet/changepoints                       ║
# ║     - Multiple related series → VAR                                  ║
# ║                                                                      ║
# ║  3. INTERPRET RESULTS CAREFULLY                                      ║
# ║     - GARCH: Focus on volatility, not mean prediction                ║
# ║     - Granger causality ≠ true causality                             ║
# ║     - Confidence intervals matter for decision-making                ║
# ║                                                                      ║
# ║  4. PRACTICAL CONSIDERATIONS                                         ║
# ║     - Simple models often outperform complex ones                    ║
# ║     - Out-of-sample performance is what matters                      ║
# ║     - Always visualize data and residuals                            ║
# ║                                                                      ║
# ╚══════════════════════════════════════════════════════════════════════╝

# %% [markdown]
# ---
#
# ## Data Sources
#
# - **Bitcoin**: Yahoo Finance (BTC-USD)
# - **Sunspots**: Wolfer sunspot dataset from statsmodels
# - **US Unemployment**: Bureau of Labor Statistics via FRED (UNRATE)
# - **Economic Data**: FRED (GDPC1, UNRATE, CPIAUCSL, FEDFUNDS)
#
# ---
#
# **End of Chapter 10: Comprehensive Review**
#
# *Course: Time Series Analysis and Forecasting*
# *Bucharest University of Economic Studies*
