# %% [markdown]
# # TSA_ch3_adf_test
#
# Chart generation code for ch3_adf_test.
# See the main regeneration script: regenerate_ch3_charts.py

# %%
# See regenerate_ch3_charts.py for the full chart generation code
# This quantlet generates: ch3_adf_test.pdf
